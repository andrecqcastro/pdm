# %% [markdown]
# # Código Base

# %%
from google.cloud import bigquery
from transformers import pipeline
import pandas as pd
import json

# %% [markdown]
# Conectando-se ao BigQuery

# %%
# Configurar credenciais para o BigQuery
service_account_json = '/content/pdm-class-rabelo-2024-cfd73100f578.json'
project_id = 'pdm-class-rabelo-2024'

# Conectar ao BigQuery
client = bigquery.Client.from_service_account_json(service_account_json)

# Consultar dados do BigQuery
query = """
    SELECT *
    FROM `pdm-class-rabelo-2024.projeto.infer_df`
    LIMIT 30
"""

query_job = client.query(query)
results = query_job.result().to_dataframe()

print(results)
# Out:
#                                           review_body
# 0   My 11 month old son is celebrating his first X...
# 1   I purchased this v-reader book for my 3 year o...
# 2   I bought this product for my 15 months old dau...
# 3   We purchased this game based on some family me...
# 4   Bought this for my daughter for Christmas, it'...
# 5   This inflatable over-the-hill walker was the h...
# 6   I know my Grandaughter's will enjoy these doll...
# 7   This is a costume, not a toy. My son loved bei...
# 8   Maybe ten million is an exaggeration - but we'...
# 9   Yes, the markders are permanent. Sigh- we play...
# 10  We bought this 2 years ago. My daughter still ...
# 11  This is a very cute stuffed animal. I bought t...
# 12  I'll admit to being a Halo geek, much more the...
# 13  The senior class at my son's school created a ...
# 14  I usually spend a lot of time researching cust...
# 15  I purchased this for my daughter for Halloween...
# 16  ***  the tenergy universal smart charger for n...
# 17  This tutu fits any 18 inch dolls.  and it fits...
# 18  5 decks of canasta caliente cards - complete i...
# 19  I watch the show Penguins of Madagascar and sk...
# 20  Be very careful when ordering from this compan...
# 21  We received this as a hand-me-down and it has ...
# 22  This toy is fantastic! It's made out of hard p...
# 23  I purchased this robe and was severely disappo...
# 24  Our 9 year old Grand daughter was thrilled wit...
# 25  I absolutely love this figure ! The detailing ...
# 26  great buy and everyone loved it at my son's fi...
# 27  These Butterfly's are hilarious!!!  I love put...
# 28  As soon as I opened this toy for our 3yr old g...
# 29  [[ASIN:B00327TL94 Little Tikes Spray and Rescu...

# %% [markdown]
# Carregando modelo de predição

# %%
# Carregar modelo de análise de sentimento do Hugging Face
model_name = "EdwardSJ151/bert-amazon-reviews"
sentiment_model = pipeline("text-classification", model=model_name)
# Out:
# Device set to use cpu

# %%
# Fazer inferência
results['sentiment'] = results['review_body'].apply(lambda x: sentiment_model(x)[0]['label'])
results['score'] = results['review_body'].apply(lambda x: sentiment_model(x)[0]['score'])

# Exibir resultados
print(results.head())

# Salvar resultados em um arquivo CSV
results.to_csv('sentiment_results.csv', index=False)
# Out:
#                                          review_body sentiment     score
# 0  My 11 month old son is celebrating his first X...   LABEL_2  0.714434
# 1  I purchased this v-reader book for my 3 year o...   LABEL_1  0.700522
# 2  I bought this product for my 15 months old dau...   LABEL_1  0.976139
# 3  We purchased this game based on some family me...   LABEL_2  0.962867
# 4  Bought this for my daughter for Christmas, it'...   LABEL_2  0.877389

# %% [markdown]
# Verificando as predições

# %%
# Iterar sobre cada linha completa
for index, row in results.iterrows():
    print(f"Linha {index}: {row.to_dict()}")
# Out:
# Linha 0: {'review_body': "My 11 month old son is celebrating his first Xmas this year, so we got him some Little People toys, including this ice cream truck.  It's super cute and sturdy.  It plays a little song when you press the drive down.  It's a sweet addition to the set  (no pun intended!)", 'sentiment': 'LABEL_2', 'score': 0.7144336104393005}
# Linha 1: {'review_body': "I purchased this v-reader book for my 3 year old son.  He Loves the v-reader.  Very easy to use and educational.  I'm excited about the Pooh book because it appears to be educational and fun.", 'sentiment': 'LABEL_1', 'score': 0.7005224823951721}
# Linha 2: {'review_body': "I bought this product for my 15 months old daughter. She loves crayons, pencils, stamps etc. I wanted to introduce her to watercolors and do some potato-stamping. I found it a bit odd that you couldn't just get watercolors everywhere. I grew up with pelikan watercolors but they are a bit pricey here. I wasn't expecting much in comparison because of the other reviews. Well, the colors are fine and my little one can mess with them and it has 24 colors. But the quality isn't that good. The colors aren't really bright. So for now it's really fine because she can get creative and learn with them (and they are washable, which is an absolut plus for really little artists). But if she gets older and still likes to paint with watercolors she will get a set from Pelikan.", 'sentiment': 'LABEL_1', 'score': 0.9761385917663574}
# Linha 3: {'review_body': "We purchased this game based on some family members that raved about it. They were right. It's fun, and can be a bit challenging (and frustrating) at times. It's great for kids, because they can improve their spelling and vocab with it, too. We've played quite a few games of this and it does not get boring! And, it's extremely portable. Love!", 'sentiment': 'LABEL_2', 'score': 0.962867021560669}
# Linha 4: {'review_body': "Bought this for my daughter for Christmas, it's very cute and a great price. I think she is going to love this.", 'sentiment': 'LABEL_2', 'score': 0.8773893117904663}
# Linha 5: {'review_body': "This inflatable over-the-hill walker was the hit of the party.  It's good-sized, has really funny signs printed all over it, and didn't take very long to blow up.", 'sentiment': 'LABEL_2', 'score': 0.9522135257720947}
# Linha 6: {'review_body': "I know my Grandaughter's will enjoy these dolls.  And I appreciate that they also contribute to the help for the world's hungry childen.", 'sentiment': 'LABEL_2', 'score': 0.5865966081619263}
# Linha 7: {'review_body': "This is a costume, not a toy. My son loved being Goku for Halloween. I'd give this costume A++. I would totally recommend this item to family and friends.", 'sentiment': 'LABEL_1', 'score': 0.5850332975387573}
# Linha 8: {'review_body': "Maybe ten million is an exaggeration - but we're close! My son has been playing with Legos since he could sit up and chew on a Duplo. I wanted to drop a note to the Lego Company to say thank you. This winter my son will be 13 and we are still able to buy him great sets that he enjoys. In fact, his favorite wrapped gifts are always the ones that rattle. :-) This alien ship will be under the tree soon.<br /><br />Thank you for offering such a wide variety of sets. The fact that you can capture the imagination of kids aged 2 to teenage years and beyond is fantastic. In all that time we've never had a problem with fit or defective parts. Everything is very well made.<br /><br />In case you're wondering how many Legos we own and if I was serious about the ten million - take a peek at the image I uploaded. That is a 30 gallon bin. We are close, aren't we?<br /><br />Thanks Lego!!", 'sentiment': 'LABEL_2', 'score': 0.9883516430854797}
# Linha 9: {'review_body': 'Yes, the markders are permanent. Sigh- we played with this at a friends house and found this out. If you use Murphys oil soap- this will take it out, but does require a bit of scrubbing!', 'sentiment': 'LABEL_1', 'score': 0.5570651888847351}
# Linha 10: {'review_body': "We bought this 2 years ago. My daughter still loves it! She has taken good care of it and it has lasted. She has added MANY pieces to it. She has played with it by herself for hours and with her friends when they come over. Wonderful for imagination. It looks so pretty in her room. She is 12 now and we plan on selling it. It has been well worth it. We could have bought it at a younger age but we didn't know she liked barbies/barbie houses till we bought it.  She would rate it a 5 along with us (her parents).", 'sentiment': 'LABEL_2', 'score': 0.9803470373153687}
# Linha 11: {'review_body': "This is a very cute stuffed animal. I bought two for the young girls in my family. They like blue and these rhinos are adorable, so its a winning situation. I haven't seen the web portion for the rhino, since these are gifts, but as stuffed animals go, this little baby blue rhino is a wonderful choice.", 'sentiment': 'LABEL_2', 'score': 0.9734473824501038}
# Linha 12: {'review_body': "I'll admit to being a Halo geek, much more the story and mythos than the online play. These helmets are roughly 1/6 scale and very detailed and rugged. I bought them to put on my sons shelf because they are just helmets, what else could you do with them? Well they are a toy in themselves to my four year old and he enjoyed them as much as his GI Joes. So I've seen first hand that despite their 'display' sort of build they are as rugged as any solid piece of plastic can be. I find them on AmazonMP for around $5 for a 3 set package including shipping. At that price you aren't risking much.", 'sentiment': 'LABEL_2', 'score': 0.6109215021133423}
# Linha 13: {'review_body': 'The senior class at my son\'s school created a Candy Land display - the mustaches were bought for Lord Licorice\'s costume - the \\\\"stash\\\\" was fun and great quality! And we have several extra for future occasions!', 'sentiment': 'LABEL_1', 'score': 0.9844063520431519}
# Linha 14: {'review_body': 'I usually spend a lot of time researching customer reviews before purchasing items online.  This case was no different, and this product definitely lives up to the positive reviews.  The colors are not bad at all; in fact, I prefer the muted grays with pops of purple, pink, and blue to the pastels that appear in the picture.  I was surprised to see so many reviewers complain about the colors.  This product is more for parents than children, so I think it\'s silly to worry about how \\\\"they are not kid-friendly colors.\\\\"  If anything, the colors complement the current trends in diaper bags and other baby gear basics.  The formula easily dispenses from the funnel, which is easy to remove and adjust.  The design makes it easy to quickly fix up a bottle, even in the most hectic of situations.  I used this at a football game and found it immeasurably easier than dealing with the formula canister.  You also don\'t have to be as worried about washing your hands or locating your hand sanitizer first, as your hands need not come in contact with the powder once it\'s measured into the individual containers.  I highly recommend this product!', 'sentiment': 'LABEL_2', 'score': 0.583285927772522}
# Linha 15: {'review_body': 'I purchased this for my daughter for Halloween.  She was so excited to be Captain America.  It is made of cheap materials, and even though it was much too large for her (I did that on purpose) The seams started to split just after the 1 wearing.  I love to purchase costumes for her to play dress up with all year.  But this one will not be able to do that.  I think she can wear it 2 more times and it will split.', 'sentiment': 'LABEL_0', 'score': 0.5944443345069885}
# Linha 16: {'review_body': '***  the tenergy universal smart charger for nimh/nicd battery packs was ordered on 9-30-11 and arrived 10-4 along with other items. the only padding in the shipping carton was an air pack thrown on top of the products. the air pack arrived deflated.  website description states: \\\\"...worldwide usage with 120-240v ac accessories included...\\\\" this is not true: you will need to purchase a separate converter and adapters to plug into a 240 volt outlet.  ***', 'sentiment': 'LABEL_1', 'score': 0.8015984296798706}
# Linha 17: {'review_body': 'This tutu fits any 18 inch dolls.  and it fits) Even the shoes and tights will fit the doll.  Really impressed!', 'sentiment': 'LABEL_2', 'score': 0.9899120926856995}
# Linha 18: {'review_body': '5 decks of canasta caliente cards - complete instructions - card rack - a full evening of entertainment easily for a group of 10-12 people.  Wonderful!!!', 'sentiment': 'LABEL_2', 'score': 0.9700826406478882}
# Linha 19: {'review_body': 'I watch the show Penguins of Madagascar and skipper is one of my favorite characters and I am glad I made this purchase. Ty Beanie Baby Skipper is fun to hug and snuggle.', 'sentiment': 'LABEL_2', 'score': 0.9095825552940369}
# Linha 20: {'review_body': "Be very careful when ordering from this company.  They will NOT take any returns, no matter if it's their fault. I received an item that was missing parts AND not as pictured and they refused to take it back....oh yeah...there's fineprint about returns right before halloween.  BUY YOUR COSTUME FROM ANOTHER COMPANY!", 'sentiment': 'LABEL_0', 'score': 0.9170293807983398}
# Linha 21: {'review_body': "We received this as a hand-me-down and it has proven to be the absolute best toy we own! We received it when my son was 8 months old and he's now 1 year.  I am not exaggerating - he seriuosly plays with this toy every single day for 30-60 minutes.  Doesn't sound like a lot but it really is - he never gets tired of going in and out of the door and he loves the wheel on top that goes from daytime to night time.  As he has gotten older I've noticed that he will focus on a different aspect of the toy that he didn't fully notice before (I'm shocked at how many things there are to play with).  Lately he thinks the doorbell is hilarious and will press it over and over and giggle when it makes a sound and lights up the house light.  One thing I think is genious (thank you Fisher Price) is the fact that there is a space at the top of the door to allow my son to hold onto the door and swing it shut and it doesn't close his hand in the door! I didn't know how much we needed this toy until we have it - if anything ever happened to it, I'd pay any amount of money to replace it!", 'sentiment': 'LABEL_2', 'score': 0.9350613951683044}
# Linha 22: {'review_body': "This toy is fantastic! It's made out of hard plastic and it's durable. Articulation points are great. I've also purchase the green goblin and with both of them it makes a cool display set! I recommend this to any Spider-man or Marvel fans!", 'sentiment': 'LABEL_2', 'score': 0.9833741188049316}
# Linha 23: {'review_body': 'I purchased this robe and was severely disappointed when I realized a LESS EXPENSIVE, MORE AUTHENTIC robe was on the market!  CONS:  - This robe is NOT completely authentic  - The colors are inaccurate, and the crest is poor quality  - It is only available to purchase in two sizes  GOOD NEWS!  - A 100% authentic robe IS on the market  - Purchase a Gryffindor Robe from the Universal Studios Online Store (from The Wizarding World of Harry Potter), and you will NOT be disappointed.  THE UNIVERSAL STUDIOS ROBE:  - 100% AUTHENTIC ROBE  - You will save 33% with the purchase from Universal [not the WB Shop] (LESS EXPENSIVE!)  - The colors are perfect (accurately match the film with both the burgundy & gold)  - The crest on the robe is perfect  - The feel of the robe is lightweight, comfortable, and durable  - Universal offers SEVERAL available sizes for their robes--which will fit your body accurately  **Say NO to this robe, say NO to the WB Shop, and visit the Universal Studios Online Store today!**', 'sentiment': 'LABEL_1', 'score': 0.7435572147369385}
# Linha 24: {'review_body': 'Our 9 year old Grand daughter was thrilled with the Melissa and Doug doll house furniture! The pieces were well made and durable. All were scaled to be good with each other in the doll house.', 'sentiment': 'LABEL_2', 'score': 0.8346217274665833}
# Linha 25: {'review_body': 'I absolutely love this figure ! The detailing is off the charts ! I was skeptical at first because the product description did not mention how big it was gonna be, but it turned out to be around 6 inches which I was hoping for. The accessories are cool - his trademark leather coat which you can remove and his trademark baseball bat.', 'sentiment': 'LABEL_2', 'score': 0.9939409494400024}
# Linha 26: {'review_body': "great buy and everyone loved it at my son's first birthday party. highly recommend this product for sesame street party.", 'sentiment': 'LABEL_2', 'score': 0.9854989051818848}
# Linha 27: {'review_body': "These Butterfly's are hilarious!!!  I love putting them in books, card, magazines, or whatever I can find for people to open them up and them fly out.  I love it.  These are good ones too.  I just wish they had more options for different designs and colors.", 'sentiment': 'LABEL_2', 'score': 0.9458999633789062}
# Linha 28: {'review_body': "As soon as I opened this toy for our 3yr old girl, she placed it right in the house, and sent the mom straight to bed. It's easy for her to use. Although, the bed itself if pretty big, but its still workable.", 'sentiment': 'LABEL_1', 'score': 0.6978472471237183}
# Linha 29: {'review_body': "[[ASIN:B00327TL94 Little Tikes Spray and Rescue Fire Truck]] I am very disappointed! I ordered this gift for my son's birthday. It arrived very quickly. I started putting it together and soon realized I was missing pieces. I am missing the eye plate and eyes and all the decals. Now I have to go out and find something else to give him. So upset! I really wanted thes pieces so I can give him what I  wanted to give him. Waste of money.I don't know what to do to fix this.", 'sentiment': 'LABEL_0', 'score': 0.8970173001289368}

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Carregar o modelo e o tokenizer
model_name = "EdwardSJ151/bert-amazon-reviews"
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Listar as labels possíveis
labels = model.config.id2label
print("Labels possíveis:", labels)
# Out:
# Labels possíveis: {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'}

# %% [markdown]
# 'LABEL_0': negativo
#
# 'LABEL_1': neutro
#
# 'LABEL_2': positivo

# %% [markdown]
# # main.py

# %%
# !pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.2)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 4.8 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: starlette, fastapi
# Successfully installed fastapi-0.115.6 starlette-0.41.3

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from typing import List
from transformers import pipeline

# Carregar modelo de análise de sentimento
model_name = "EdwardSJ151/bert-amazon-reviews"
sentiment_model = pipeline("text-classification", model=model_name)

# Inicializar o aplicativo FastAPI
app = FastAPI()

# Definir o esquema de entrada
class SentimentInput(BaseModel):
    texts: List[str]  # Lista de textos para análise

# Definir o esquema de saída
class SentimentOutput(BaseModel):
    label: str
    score: float

@app.post("/sentiment-analysis", response_model=List[SentimentOutput])
async def analyze_sentiments(input_data: SentimentInput):
    try:
        # Fazer inferência para cada texto da entrada
        predictions = [
            {
                "label": sentiment_model(text)[0]["label"],
                "score": sentiment_model(text)[0]["score"]
            }
            for text in input_data.texts
        ]

        return predictions

    except Exception as e:
        raise HTTPException(status_code=400, detail=f"Erro na predição: {str(e)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/885 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# Teste simples embutido
if __name__ == "__main__":
    # Dados de teste
    test_input = SentimentInput(
        texts=[
            "This product is amazing!",
            "I am very disappointed with the quality.",
            "It works fine, but could be better."
        ]
    )

    # Simular uma chamada ao endpoint
    try:
        print("Running test...")
        predictions = [
            {
                "label": sentiment_model(text)[0]["label"],
                "score": sentiment_model(text)[0]["score"]
            }
            for text in test_input.texts
        ]

        # Exibir os resultados do teste
        for idx, prediction in enumerate(predictions):
            print(f"Text {idx + 1}: {test_input.texts[idx]}")
            print(f"Prediction: {prediction}")
            print()

    except Exception as e:
        print(f"Erro no teste: {e}")
# Out:
# Running test...
# Text 1: This product is amazing!
# Prediction: {'label': 'LABEL_2', 'score': 0.9928032755851746}
#
# Text 2: I am very disappointed with the quality.
# Prediction: {'label': 'LABEL_0', 'score': 0.9488065838813782}
#
# Text 3: It works fine, but could be better.
# Prediction: {'label': 'LABEL_1', 'score': 0.8292544484138489}
